# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 2.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 16.6 MB 10.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.1 MB 13.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 7.7 MB 14.8 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
caba = gpd.read_file('mapa/caba.geojson')

# %%
caba.plot()
# Out:
# <AxesSubplot:>

# %%
barrios = pd.read_csv('datasets/barrios.csv',sep=';')
barrios.rename(columns={'WKT':'geometry'}, inplace=True)

gpd.GeoDataFrame(barrios).plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [60], in <cell line: 4>()
#       1 barrios = pd.read_csv('datasets/barrios.csv',sep=';')
#       2 barrios.rename(columns={'WKT':'geometry'}, inplace=True)
# ----> 4 gpd.GeoDataFrame(barrios).plot()
#
# File ~/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py:963, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     961 kind = kwargs.pop("kind", "geo")
#     962 if kind == "geo":
# --> 963     return plot_dataframe(data, *args, **kwargs)
#     964 if kind in self._pandas_kinds:
#     965     # Access pandas plots
#     966     return PlotAccessor(data)(kind=kind, **kwargs)
#
# ...
